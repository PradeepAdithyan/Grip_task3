# %% [markdown]
# # Prediction Using Decision Tree Algoritm

# %% [markdown]
# Author : M Pradeep Adithyan

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
iris.data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier,export_graphviz

# %%
dt=DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
trainX,testX,trainY,testY=train_test_split(iris.data,iris.target)

# %%
dt.fit(trainX,trainY)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
export_graphviz(dt,'dt.tree')

# %%
dt.predict(testX)
# Out:
# array([0, 1, 1, 0, 0, 0, 0, 2, 1, 2, 2, 0, 2, 0, 1, 1, 1, 2, 1, 2, 2, 0,
#        2, 2, 0, 2, 0, 1, 1, 0, 1, 1, 0, 0, 2, 2, 2, 1])

# %% [markdown]
# # Visualizing the Tree

# %% [markdown]
# http://www.webgraphviz.com/

# %% [markdown]
# ![68747470733a2f2f6769746875622e636f6d2f6177616e74696b2f6d616368696e652d6c6561726e696e672d736c696465732f626c6f622f6d61737465722f6474362e504e473f7261773d74727565.png](attachment:68747470733a2f2f6769746875622e636f6d2f6177616e74696b2f6d616368696e652d6c6561726e696e672d736c696465732f626c6f622f6d61737465722f6474362e504e473f7261773d74727565.png)

# %% [markdown]
# You can now feed any new/test data to this classifer and it would be able to predict the right class accordingly.
